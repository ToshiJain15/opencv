# %%
import cv2
import os
import urllib.request

# colab compatibility patch
def imshow(name, img):
    try:
        from google.colab.patches import cv2_imshow
        cv2_imshow(img)
    except ImportError:
        imshow(name, img)

# download missing xml and assets if in colab
assets = {
    'face.xml': 'https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml',
    'haarcascade_fullbody.xml': 'https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_fullbody.xml',
    'myfirst.png': 'https://raw.githubusercontent.com/ToshiJain15/opencv/master/docs/assets/myfirst.png',
    'TB.jpg': 'https://raw.githubusercontent.com/ToshiJain15/opencv/master/docs/assets/TB.jpg',
    'i.jpg': 'https://raw.githubusercontent.com/ToshiJain15/opencv/master/docs/assets/i.jpg'
}

for filename, url in assets.items():
    if not os.path.exists(filename):
        print(f'Downloading {filename}...')
        try: urllib.request.urlretrieve(url, filename)
        except: print(f'Failed to download {filename}')

# %% [markdown]
# ## Part 3:
# 1. Study about haar cascade algoritms.
# 2. Try to import haarcascade algoritms for face detection in ide (.xml).
# 3. Prepare a model which will detect the face and boundry it using blue box (rectangle).

# %%
#face detection in image
import cv2

# %%
image=cv2.imread("myfirst.png")

# %%
imshow("baby",image)
cv2.waitKey(0)
# Out:
# -1

# %%
gray=cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
imshow("Gray image",gray)
cv2.waitKey(0)
# Out:
# -1

# %%
#haarcascade classifier face.xml pretrauned model in it #cordinates of fav2ce
facecasecade=cv2.CascadeClassifier('face.xml')

faces=facecasecade.detectMultiScale(gray,scaleFactor=1.2, minNeighbors=5, #x+w, y+h
                                    minSize=(20,20))
print(faces)
# Out:
# [[ 71  48 103 103]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(255,0,0),4)#topleft , bottom left, if at end 255=redcolor, width of rect

# %%
imshow("face",image)
cv2.waitKey(0)
# Out:
# -1

# %%
import numpy as np
import cv2
#create a black image

img = np.zeros((300,300,3), np.uint8)
img=cv2.line(img,(0,0),(101,101),(255,0,0),4)
img=cv2.circle(img,(150,130),50,(0,0,255),-1)

imshow("frame",img)
cv2.waitKey(0)
# Out:
# -1

# %%
#font
font=cv2.FONT_HERSHEY_SIMPLEX
#fontscale
fontscale=1
img=cv2.putText(img,"Happy",(200,50),font,fontscale,(255,0,0),5)
imshow("frame",img)
cv2.waitKey(0)
# Out:
# -1
